# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Part1: 탐색적 데이터 분석(EDA)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/MyDrive//kaggle/01.Titanic(Machine Learning from Disaster)/data/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.isnull().sum() # null값이 있는 지 확인
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# age, cabin, embarked만 null값 있는 것을 확인

# %% [markdown]
# #### 얼마나 생존했는지 확인

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True) # survived 컬럼 값을 값 별로 센 후 pie 그래프로 보여준다.
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# 38.4%만 생존

# %% [markdown]
# ## Feature 분석

# %% [markdown]
# ### 1. 성별(범주형 특징)

# %%
data.groupby(['Sex', 'Survived']).count() # 성별별로 생존여부 값을 묶어서 각각의 수를 보여줌
# Out:
#                  PassengerId  Pclass  Name  Age  ...  Ticket  Fare  Cabin  Embarked
# Sex    Survived                                  ...
# female 0                  81      81    81   64  ...      81    81      6        81
#        1                 233     233   233  197  ...     233   233     91       231
# male   0                 468     468   468  360  ...     468   468     62       468
#        1                 109     109   109   93  ...     109   109     45       109
#
# [4 rows x 10 columns]

# %%
data.groupby(['Sex', 'Survived'])['Survived'].count() # 성별별로 생존여부 값을 묶어서 생존여부 수를 보여줌
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
data[['Sex', 'Survived']]
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# ..      ...       ...
# 886    male         0
# 887  female         1
# 888  female         0
# 889    male         1
# 890    male         0
#
# [891 rows x 2 columns]

# %%
data[['Sex', 'Survived']].groupby(['Sex']).mean()
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# 남성보다 여성의 생존률이 더 높은 것을 볼 수 있다.

# %% [markdown]
# ### 2. 승객 등급(서수형 특징)

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1e4a460c_3635_11ec_9730_0242ac1c0002row0_col0,#T_1e4a460c_3635_11ec_9730_0242ac1c0002row1_col1,#T_1e4a460c_3635_11ec_9730_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1e4a460c_3635_11ec_9730_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_1e4a460c_3635_11ec_9730_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_1e4a460c_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_1e4a460c_3635_11ec_9730_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_1e4a460c_3635_11ec_9730_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_1e4a460c_3635_11ec_9730_0242ac1c0002row2_col2{
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %% [markdown]
# 1등급 승객의 생존률이 그 수에 비해서 높은 것을 알 수 있음

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1e96dc74_3635_11ec_9730_0242ac1c0002row0_col0,#T_1e96dc74_3635_11ec_9730_0242ac1c0002row0_col1,#T_1e96dc74_3635_11ec_9730_0242ac1c0002row0_col3,#T_1e96dc74_3635_11ec_9730_0242ac1c0002row3_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1e96dc74_3635_11ec_9730_0242ac1c0002row0_col2,#T_1e96dc74_3635_11ec_9730_0242ac1c0002row1_col2{
#             background-color:  #f1f866;
#             color:  #000000;
#         }#T_1e96dc74_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_1e96dc74_3635_11ec_9730_0242ac1c0002row1_col1{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_1e96dc74_3635_11ec_9730_0242ac1c0002row1_col3{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_1e96dc74_3635_11ec_9730_0242ac1c0002row2_col0{
#             background-color:  #a7d366;
# ...

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# ### 3. 나이(연속적 특징)

# %%
print('가장 나이가 많은 승객:',data['Age'].max(),'살')
print('최연소 승객:',data['Age'].min(),'살')
print('승객들 평균 나이:',data['Age'].mean(),'살')
# Out:
# 가장 나이가 많은 승객: 80.0 살
# 최연소 승객: 0.42 살
# 승객들 평균 나이: 29.69911764705882 살

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.')

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data['Initial']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Initial, Length: 891, dtype: object

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col0,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col1,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col3,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col4,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col5,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col7,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col8,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col12,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col15,#T_1f3de406_3635_11ec_9730_0242ac1c0002row0_col16,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col2,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col6,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col9,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col10,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col11,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col13,#T_1f3de406_3635_11ec_9730_0242ac1c0002row1_col14{
#             background-color:  #ffff66;
#             color:  #000000;
# ...

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# #### 나이에 있는 null값 채우기

# %%
data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# ### 4. 탑승한 곳(범주형 특징)

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_20677de2_3635_11ec_9730_0242ac1c0002row0_col0,#T_20677de2_3635_11ec_9730_0242ac1c0002row1_col2{
#             background-color:  #fcfe66;
#             color:  #000000;
#         }#T_20677de2_3635_11ec_9730_0242ac1c0002row0_col1{
#             background-color:  #d2e866;
#             color:  #000000;
#         }#T_20677de2_3635_11ec_9730_0242ac1c0002row0_col2{
#             background-color:  #f2f866;
#             color:  #000000;
#         }#T_20677de2_3635_11ec_9730_0242ac1c0002row0_col3{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_20677de2_3635_11ec_9730_0242ac1c0002row0_col4,#T_20677de2_3635_11ec_9730_0242ac1c0002row2_col3{
#             background-color:  #e8f466;
#             color:  #000000;
# ...

# %% [markdown]
# #### 승선항의 생존 가능성

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# #### 탑승한 곳 값이 null인 것 채우기

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()
# Out:
# False

# %% [markdown]
# #### 5. 가족 (별개의 특징)

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_21d48e72_3635_11ec_9730_0242ac1c0002row0_col0,#T_21d48e72_3635_11ec_9730_0242ac1c0002row0_col1{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_21d48e72_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #c4e266;
#             color:  #000000;
#         }#T_21d48e72_3635_11ec_9730_0242ac1c0002row1_col1{
#             background-color:  #77bb66;
#             color:  #000000;
#         }#T_21d48e72_3635_11ec_9730_0242ac1c0002row2_col0,#T_21d48e72_3635_11ec_9730_0242ac1c0002row4_col0{
#             background-color:  #f9fc66;
#             color:  #000000;
#         }#T_21d48e72_3635_11ec_9730_0242ac1c0002row2_col1{
#             background-color:  #f0f866;
#             color:  #000000;
#         }#T_21d48e72_3635_11ec_9730_0242ac1c0002row3_col0,#T_21d48e72_3635_11ec_9730_0242ac1c0002row3_col1{
#             background-color:  #fbfd66;
#             color:  #000000;
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_226552cc_3635_11ec_9730_0242ac1c0002row0_col0,#T_226552cc_3635_11ec_9730_0242ac1c0002row0_col1,#T_226552cc_3635_11ec_9730_0242ac1c0002row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_226552cc_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #7bbd66;
#             color:  #000000;
#         }#T_226552cc_3635_11ec_9730_0242ac1c0002row1_col1{
#             background-color:  #8ac466;
#             color:  #000000;
#         }#T_226552cc_3635_11ec_9730_0242ac1c0002row1_col2{
#             background-color:  #c6e266;
#             color:  #000000;
#         }#T_226552cc_3635_11ec_9730_0242ac1c0002row2_col0,#T_226552cc_3635_11ec_9730_0242ac1c0002row4_col2{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_226552cc_3635_11ec_9730_0242ac1c0002row2_col1{
#             background-color:  #eef666;
#             color:  #000000;
# ...

# %% [markdown]
# ### 6. Parch

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_226bab54_3635_11ec_9730_0242ac1c0002row0_col0,#T_226bab54_3635_11ec_9730_0242ac1c0002row0_col1,#T_226bab54_3635_11ec_9730_0242ac1c0002row0_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_226bab54_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #cfe766;
#             color:  #000000;
#         }#T_226bab54_3635_11ec_9730_0242ac1c0002row1_col1{
#             background-color:  #c2e066;
#             color:  #000000;
#         }#T_226bab54_3635_11ec_9730_0242ac1c0002row1_col2{
#             background-color:  #dbed66;
#             color:  #000000;
#         }#T_226bab54_3635_11ec_9730_0242ac1c0002row2_col0{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_226bab54_3635_11ec_9730_0242ac1c0002row2_col1{
#             background-color:  #e1f066;
#             color:  #000000;
#         }#T_226bab54_3635_11ec_9730_0242ac1c0002row2_col2{
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
plt.show()

# %% [markdown]
# ### 7. 운임 요금(지속적 특징)

# %%
print('최고 운임 요금:',data['Fare'].max())
print('최저 운임 요금:',data['Fare'].min())
print('평균 운임 요금:',data['Fare'].mean())
# Out:
# 최고 운임 요금: 512.3292
# 최저 운임 요금: 0.0
# 평균 운임 요금: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# ### 기능 간의 상관 관계

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# ## Part2: 기능 엔지니어링 및 데이터 정리

# %%
data['Age_band']=0
data.loc[data['Age']<=16,'Age_band']=0
data.loc[(data['Age']>16)&(data['Age']<=32),'Age_band']=1
data.loc[(data['Age']>32)&(data['Age']<=48),'Age_band']=2
data.loc[(data['Age']>48)&(data['Age']<=64),'Age_band']=3
data.loc[data['Age']>64,'Age_band']=4
data.head(2)
# Out:
#    PassengerId  Survived  Pclass  ... Embarked Initial  Age_band
# 0            1         0       3  ...        S      Mr         1
# 1            2         1       1  ...        C     Mrs         2
#
# [2 rows x 14 columns]

# %%
data['Age_band'].value_counts().to_frame().style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
# #T_23c0a2b6_3635_11ec_9730_0242ac1c0002row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_23c0a2b6_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #d8ec66;
#             color:  #000000;
#         }#T_23c0a2b6_3635_11ec_9730_0242ac1c0002row2_col0{
#             background-color:  #40a066;
#             color:  #000000;
#         }#T_23c0a2b6_3635_11ec_9730_0242ac1c0002row3_col0{
#             background-color:  #289366;
#             color:  #000000;
#         }#T_23c0a2b6_3635_11ec_9730_0242ac1c0002row4_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_23c0a2b6_3635_11ec_9730_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age_band</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
sns.factorplot('Age_band','Survived',data=data,col='Pclass')
plt.show()

# %% [markdown]
# ### 가족 규모와 혼자

# %%
data['Family_Size']=0
data['Family_Size']=data['Parch']+data['SibSp']#family size
data['Alone']=0
data.loc[data.Family_Size==0,'Alone']=1#Alone

f,ax=plt.subplots(1,2,figsize=(18,6))
sns.factorplot('Family_Size','Survived',data=data,ax=ax[0])
ax[0].set_title('Family_Size vs Survived')
sns.factorplot('Alone','Survived',data=data,ax=ax[1])
ax[1].set_title('Alone vs Survived')
plt.show()

# %%
sns.factorplot('Alone','Survived',data=data,hue='Sex',col='Pclass')
plt.show()

# %% [markdown]
# ### 운임 요금 범위

# %%
data['Fare_Range']=pd.qcut(data['Fare'],4)
data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_258c5798_3635_11ec_9730_0242ac1c0002row0_col0{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_258c5798_3635_11ec_9730_0242ac1c0002row1_col0{
#             background-color:  #b9dc66;
#             color:  #000000;
#         }#T_258c5798_3635_11ec_9730_0242ac1c0002row2_col0{
#             background-color:  #54aa66;
#             color:  #000000;
#         }#T_258c5798_3635_11ec_9730_0242ac1c0002row3_col0{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_258c5798_3635_11ec_9730_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Survived</th>    </tr>    <tr>        <th class="index_name level0" >Fare_Range</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
data['Fare_cat']=0
data.loc[data['Fare']<=7.91,'Fare_cat']=0
data.loc[(data['Fare']>7.91)&(data['Fare']<=14.454),'Fare_cat']=1
data.loc[(data['Fare']>14.454)&(data['Fare']<=31),'Fare_cat']=2
data.loc[(data['Fare']>31)&(data['Fare']<=513),'Fare_cat']=3

# %%
sns.factorplot('Fare_cat','Survived',data=data,hue='Sex')
plt.show()

# %% [markdown]
# ### 문자열 값을 숫자로 변환

# %%
data['Sex'].replace(['male','female'],[0,1],inplace=True)
data['Embarked'].replace(['S','C','Q'],[0,1,2],inplace=True)
data['Initial'].replace(['Mr','Mrs','Miss','Master','Other'],[0,1,2,3,4],inplace=True)

# %%
data.drop(['Name','Age','Ticket','Fare','Cabin','Fare_Range','PassengerId'],axis=1,inplace=True)
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':20})
fig=plt.gcf()
fig.set_size_inches(18,15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
